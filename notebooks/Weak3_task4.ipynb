# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/MachineLearningRating_v3.csv'
df = pd.read_csv(file_path, delimiter='|')  # Use '|' as delimiter
df.info()
df.describe()
# Out:
# <ipython-input-4-fef2fc7be864>:4: DtypeWarning: Columns (0,3,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter='|')  # Use '|' as delimiter
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  object
#  1   PolicyID                  973382 non-null   float64
#  2   TransactionMonth          973382 non-null   object
#  3   IsVATRegistered           973382 non-null   object
#  4   Citizenship               973382 non-null   object
#  5   LegalType                 973382 non-null   object
#  6   Title                     973382 non-null   object
#  7   Language                  973382 non-null   object
#  8   Bank                      831862 non-null   object
# ...

# %%
print(df.columns)
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Fill missing values in numeric columns with the median of each column
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
# Select non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=['float64', 'int64']).columns

# Fill missing values in non-numeric columns with the mode of each column
for col in non_numeric_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
# Out:
# <ipython-input-27-150a5af3363a>:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(df[col].mode()[0])

# %%
df = pd.get_dummies(df, columns=['Province', 'Gender', 'PostalCode'], drop_first=True)

# %%
df['ProfitMargin'] = df['TotalPremium'] - df['TotalClaims']

# %%
X = df.drop(columns=['TotalClaims'])  # Features
y = df['TotalClaims']  # Target

# %%
# !pip install pandas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Assuming 'MachineLearningRating_v3.csv' is in the current directory or adjust the path accordingly
file_path = 'MachineLearningRating_v3.csv'
df = pd.read_csv(file_path, delimiter='|')  # Load the dataframe

# ... (Rest of the data preprocessing code as provided earlier) ...

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Fill missing values in numeric columns with the median of each column
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# Select non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=['float64', 'int64']).columns

# Fill missing values in non-numeric columns with the mode of each column
for col in non_numeric_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

df = pd.get_dummies(df, columns=['Province', 'Gender', 'PostalCode'], drop_first=True)

df['ProfitMargin'] = df['TotalPremium'] - df['TotalClaims']

# Split the data into features and target
X = df.drop(columns=['TotalClaims'])  # Features
y = df['TotalClaims']  # Target

# %%
# !pip install pandas scikit-learn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from google.colab import drive
drive.mount('/content/drive')
# Assuming 'MachineLearningRating_v3.csv' is in the current directory or adjust the path accordingly
import pandas as pd

file_path = '/content/drive/MyDrive/MachineLearningRating_v3.csv'
# ... (Rest of the data preprocessing code as provided earlier) ...
import pandas as pd

file_path = '/content/drive/MyDrive/MachineLearningRating_v3.csv'
df = pd.read_csv(file_path, delimiter='|')  # Use '|' as delimiter
df.info()
df.describe()

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Fill missing values in numeric columns with the median of each column
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# Select non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=['float64', 'int64']).columns

# Fill missing values in non-numeric columns with the mode of each column
for col in non_numeric_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

df = pd.get_dummies(df, columns=['Province', 'Gender', 'PostalCode'], drop_first=True)

df['ProfitMargin'] = df['TotalPremium'] - df
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-14-d0dda5f5e3c4>:16: DtypeWarning: Columns (0,3,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter='|')  # Use '|' as delimiter
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  object
#  1   PolicyID                  973382 non-null   float64
#  2   TransactionMonth          973382 non-null   object
#  3   IsVATRegistered           973382 non-null   object
#  4   Citizenship               973382 non-null   object
#  5   LegalType                 973382 non-null   object
#  6   Title                     973382 non-null   object
# ...

# %%
import shap

explainer = shap.Explainer(xgb_model)
shap_values = explainer(X_test)

shap.summary_plot(shap_values, X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5232211b0e5f> in <cell line: 3>()
#       1 import shap
#       2
# ----> 3 explainer = shap.Explainer(xgb_model)
#       4 shap_values = explainer(X_test)
#       5
#
# NameError: name 'xgb_model' is not defined
